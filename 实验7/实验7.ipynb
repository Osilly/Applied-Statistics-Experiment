# %%
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as sta
import math
import random
import statsmodels.stats.weightstats as sw
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %% [markdown]
# # 你对志愿活动的了解情况

# %%
label = ["非常了解","了解","不太了解","不了解"]
x = [20,57,28,5]
plt.figure(figsize=(6,9))
plt.pie(x,labels=label,autopct = '%3.2f%%')
plt.show()

# %% [markdown]
# # 你是否参加过志愿者服务活动

# %%
label = ["经常参加","偶尔参加","从不参加","没机会参加"]
x = [34,62,4,10]
plt.figure(figsize=(6,9))
plt.pie(x,labels=label,autopct = '%3.2f%%')
plt.show()

# %% [markdown]
# # 你参加什么类型的志愿者服务活动

# %%
label = ["体育类志愿活动","资助类活动","宣传类活动","关爱类活动"]
x = [22,23,19,14]
plt.figure(figsize=(6,9))
plt.pie(x,labels=label,autopct = '%3.2f%%')
plt.show()

# %% [markdown]
# # 参加志愿活动，你收获了什么

# %%
label = ["光荣感与成就感","提升自己的能力","感受到社会，加深了对社会的了解","提高社会责任感"]
x = [79,72,83,77]
plt.figure(figsize=(6,9))
plt.pie(x,labels=label,autopct = '%3.2f%%')
plt.show()
